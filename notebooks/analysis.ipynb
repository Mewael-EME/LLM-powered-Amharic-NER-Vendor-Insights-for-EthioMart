# %%
import os
print(os.getcwd())
# Out:
# C:\Users\Admin\Desktop\KAIM\Week 3\Insurance_risk_analytics_week_03\notebooks

# %%
# notebooks/analysis.ipynb

# Cell 1: Imports & Setup
import os
import sys
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sys.path.append(os.path.abspath(".."))
from src.eda import summarization, missing_values, univariate, bivariate, outlier_detection


# Load Data
data_path = "insurance_data.txt"
df = summarization.load_data(data_path)
df.head()
# Out:
# C:\Users\Admin\Desktop\KAIM\Week 3\Insurance_risk_analytics_week_03\src\eda\summarization.py:7: DtypeWarning: Columns (32,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(data_path, sep='|')
# Loaded data with shape: (1000098, 52)
#    UnderwrittenCoverID  PolicyID     TransactionMonth  IsVATRegistered  \
# 0               145249     12827  2015-03-01 00:00:00             True
# 1               145249     12827  2015-05-01 00:00:00             True
# 2               145249     12827  2015-07-01 00:00:00             True
# 3               145255     12827  2015-05-01 00:00:00             True
# 4               145255     12827  2015-07-01 00:00:00             True
#
#   Citizenship          LegalType Title Language                 Bank  \
# 0              Close Corporation    Mr  English  First National Bank
# 1              Close Corporation    Mr  English  First National Bank
# ...

# %%
print(df.columns.tolist())
# Out:
# ['UnderwrittenCoverID', 'PolicyID', 'TransactionMonth', 'IsVATRegistered', 'Citizenship', 'LegalType', 'Title', 'Language', 'Bank', 'AccountType', 'MaritalStatus', 'Gender', 'Country', 'Province', 'PostalCode', 'MainCrestaZone', 'SubCrestaZone', 'ItemType', 'mmcode', 'VehicleType', 'RegistrationYear', 'make', 'Model', 'Cylinders', 'cubiccapacity', 'kilowatts', 'bodytype', 'NumberOfDoors', 'VehicleIntroDate', 'CustomValueEstimate', 'AlarmImmobiliser', 'TrackingDevice', 'CapitalOutstanding', 'NewVehicle', 'WrittenOff', 'Rebuilt', 'Converted', 'CrossBorder', 'NumberOfVehiclesInFleet', 'SumInsured', 'TermFrequency', 'CalculatedPremiumPerTerm', 'ExcessSelected', 'CoverCategory', 'CoverType', 'CoverGroup', 'Section', 'Product', 'StatutoryClass', 'StatutoryRiskType', 'TotalPremium', 'TotalClaims']

# %%
# Cell 2: Data Summarization

# Descriptive Stats for relevant numerical columns
print("Descriptive Statistics:")
display(df[["TotalPremium", "TotalClaims"]].describe())

# Data types
print("\nData Types and Structure:")
display(df.dtypes)
# Out:
# Descriptive Statistics:
#        TotalPremium   TotalClaims
# count  1.000098e+06  1.000098e+06
# mean   6.190550e+01  6.486119e+01
# std    2.302845e+02  2.384075e+03
# min   -7.825768e+02 -1.200241e+04
# 25%    0.000000e+00  0.000000e+00
# 50%    2.178333e+00  0.000000e+00
# 75%    2.192982e+01  0.000000e+00
# max    6.528260e+04  3.930921e+05
# Data Types and Structure:
# UnderwrittenCoverID           int64
# PolicyID                      int64
# TransactionMonth             object
# IsVATRegistered                bool
# Citizenship                  object
# LegalType                    object
# Title                        object
# Language                     object
# Bank                         object
# AccountType                  object
# MaritalStatus                object
# Gender                       object
# Country                      object
# Province                     object
# PostalCode                    int64
# MainCrestaZone               object
# ...

# %%
# Cell 3: Data Quality Assessment (Missing Values)
print("Missing Values Report:")
missing_values.check_missing(df)
# Out:
# Missing Values Report:
# Missing Values Report:
#                                             Column  MissingCount  \
# UnderwrittenCoverID            UnderwrittenCoverID             0
# PolicyID                                  PolicyID             0
# TransactionMonth                  TransactionMonth             0
# IsVATRegistered                    IsVATRegistered             0
# Citizenship                            Citizenship             0
# LegalType                                LegalType             0
# Title                                        Title             0
# Language                                  Language             0
# Bank                                          Bank        145961
# AccountType                            AccountType         40232
# MaritalStatus                        MaritalStatus          8259
# Gender                                      Gender          9536
# Country                                    Country             0
# ...

# %%
# Cell 4: Univariate Analysis
# Uses your module, assumes univariate.py already creates plots
sys.path.append(os.path.abspath(".."))
univariate.plot_distributions(df)
plt.show()
# Out:
#  Plotting Histograms for Numeric Columns
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 4
#       1 # Cell 4: Univariate Analysis
#       2 # Uses your module, assumes univariate.py already creates plots
#       3 sys.path.append(os.path.abspath(".."))
# ----> 4 univariate.plot_distributions(df)
#       5 plt.show()
#
# File ~\Desktop\KAIM\Week 3\Insurance_risk_analytics_week_03\src\eda\univariate.py:15, in plot_distributions(df)
#      13     sns.histplot(df[col], kde=True)
#      14     plt.title(f'Distribution of {col}')
# ---> 15     plt.savefig(f'plots/hist_{col}.png')
#      16     plt.close()
#      18 print("\n Plotting Bar Charts for Categorical Columns")
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\pyplot.py:1251, in savefig(*args, **kwargs)
#    1248 fig = gcf()
# ...

# %%
# Cell 5: Bivariate / Multivariate Analysis

# Correlation heatmap of numerical features
plt.figure(figsize=(10, 6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# %%
# Monthly change trends of TotalPremium vs TotalClaim as a function of ZipCode
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x="TotalPremium", y="TotalClaims", hue="PostalCode", alpha=0.7)
plt.title("TotalPremium vs TotalClaim by PostalCode")
plt.xlabel("Total Premium")
plt.ylabel("Total Claims")
plt.legend(loc="best", bbox_to_anchor=(1.05, 1))
plt.tight_layout()
plt.show()

# %%
# Cell 6: Data Comparison Across Geography

# Example: Compare TotalPremium per CoverType and ZipCode
plt.figure(figsize=(12, 6))
sns.boxplot(data=df, x="CoverType", y="TotalPremium", hue="PostalCode")
plt.title("Total Premium by Cover Type and ZipCode")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9816\1815985783.py:8: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   plt.tight_layout()
# C:\Users\Admin\AppData\Local\Programs\Python\Python313\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# Compare TotalPremium per PolicyType and ZipCode
plt.figure(figsize=(12, 6))
sns.boxplot(data=df, x="CoverType", y="TotalPremium")
'''
Other possible x candidates: Product, VehicleType, CoverCategory, Province and ItemType
sns.boxplot(data=df, x="CoverType", y="TotalPremium")
'''
#sns.boxplot(data=df, x="Product", y="TotalPremium")

plt.title("Total Premium by Policy Type and ZipCode")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Cell 7: Outlier Detection

# Uses your outlier module
outliers.plot_boxplots(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 4
#       1 # Cell 7: Outlier Detection
#       2
#       3 # Uses your outlier module
# ----> 4 outliers.plot_boxplots(df)
#
# NameError: name 'outliers' is not defined

# %%
# Cell 8: Creative Visualizations

# 1. Premium vs Claim ratio distribution
df["Premium_Claim_Ratio"] = df["TotalPremium"] / (df["TotalClaims"] + 1)
plt.figure(figsize=(10, 5))
sns.histplot(df["Premium_Claim_Ratio"], bins=30, kde=True, color="skyblue")
plt.title("Distribution of Premium-to-Claim Ratio")
plt.xlabel("Ratio")
plt.ylabel("Frequency")
plt.show()

# 2. Most frequent AutoMake per ZipCode
plt.figure(figsize=(4, 80))  # You might want a taller figure now
top_auto = df.groupby(["PostalCode", "make"]).size().reset_index(name="count")
top_auto = top_auto.sort_values("count", ascending=False).groupby("PostalCode").head(1)
sns.barplot(data=top_auto, y="PostalCode", x="count", hue="make", orient='h')
plt.title("Most Common AutoMake by PostalCode")
plt.tight_layout()
plt.show()
# Out:
# Column 'Month' not found for monthly trend plot.

# %%
# 3. Monthly trend of Total Premiums (assuming 'Month' column exists)
if "Month" in df.columns:
    df["Month"] = pd.to_datetime(df["Month"])
    monthly_prem = df.groupby(df["Month"].dt.to_period("M"))["TotalPremium"].sum()
    monthly_prem.plot(kind="line", marker="o", figsize=(10, 4), title="Monthly Total Premium Trend")
    plt.ylabel("Total Premium")
    plt.xlabel("Month")
    plt.show()
else:
    print("Column 'Month' not found for monthly trend plot.")
# Out:
# Column 'Month' not found for monthly trend plot.
